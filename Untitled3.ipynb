# %% [markdown]
# <a href="https://colab.research.google.com/github/swathikapendala/BATCH-11/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("sales.csv")
df.head()
# Out:
#    Sales_Order #        Date  Day     Month  Year  Customer_Age  \
# 0         261696  01-12-2021  1.0  December  2021            39
# 1         261695  01-12-2021  1.0  December  2021            44
# 2         261697  02-12-2021  2.0  December  2021            37
# 3         261698  02-12-2021  2.0  December  2021            31
# 4         261699  03-12-2021  3.0  December  2021            37
#
#               Age_Group Customer_Gender         Country            State  \
# 0        Adults (35-64)               F   United States       California
# 1        Adults (35-64)               M  United Kingdom          England
# 2        Adults (35-64)               M   United States       California
# 3  Young Adults (25-34)               F       Australia  New South Wales
# 4        Adults (35-64)               F  United  States       California
#
#   Product_Category    Sub_Category        Product_Description  Order_Quantity  \
# ...

# %%
# Out:
#   File "/tmp/ipython-input-3040106292.py", line 1
#     csv_file = "C:\Users\Pendalaswathika\OneDrive\Desktop\sales.csv"  # Replace with your desired CSV file name
#                                                                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
